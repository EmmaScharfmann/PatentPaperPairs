# %%
import pandas as pd
import glob
main_path = '/home/fs01/spec1142/Emma/PPPs/'

# %% [markdown]
# ## affiliation id name type

# %%
institutions = pd.read_csv(main_path + 'institutions_up_to_20230817.tsv' , delimiter = '\t' , usecols = ['institution_id','display_name','type'])

# %%
institutions = institutions.rename(columns = { 'institution_id' : 'affiliationid' , 'display_name' : 'name' })

# %%
institutions

# %%
institutions.to_csv(main_path + "data_to_post/clean_files/" + 'affiliationidnametype.csv' , index = False)

# %% [markdown]
# ## Authors

# %%
from google.cloud import storage
path = '/home/fs01/spec1142/Emma/'
path_to_private_key = path + "openalex-lee-c532eb059285.json"
client_storage = storage.Client.from_service_account_json(json_credentials_path=path_to_private_key)


bucket_name = 'openalex-lee'
prefix = 'OpenAlex/authors'
dl_dir = path + "PPPs/data_to_post/authors/" 
    
    
bucket = client_storage.get_bucket(bucket_or_name=bucket_name)
blobs = bucket.list_blobs(prefix=prefix)  # Get list of files
for blob in blobs:
    filename = blob.name.replace('/', '_') 
    blob.download_to_filename(dl_dir + filename)  # Download

# %%
import glob

# %%
path = '/home/fs01/spec1142/Emma/'

glob.glob(path + "PPPs/data_to_post/authors/*" )
# Out:
# ['/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_updated_date=2023-04-21.tsv',
#  '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_updated_date=2023-05-02.tsv',
#  '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_updated_date=2023-05-24.tsv',
#  '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_updated_date=2023-06-08.tsv',
#  '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_updated_date=2023-06-13.tsv',
#  '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_updated_date=2023-06-14.tsv',
#  '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_updated_date=2023-06-18.tsv',
#  '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_updated_date=2023-06-22.tsv',
#  '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_updated_date=2023-06-26.tsv',
# ...

# %%
list_files_authors = ['data_to_post/authors/OpenAlex_authors_updated_date=2023-04-21.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-05-02.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-05-24.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-06-08.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-06-13.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-06-14.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-06-18.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-06-22.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-06-26.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-06-27.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-06-28.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-06-30.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-07-02.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-07-06.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-07-14.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-07-17.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-07-20.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-07-21.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-07-25.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-07-26.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-07-27.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-07-28.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-07-29.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-07-30.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-07-31.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-08-01.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-08-02.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-08-03.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-08-04.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-08-05.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-08-06.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-08-07.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-08-08.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-08-09.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-08-10.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-08-11.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-08-12.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-08-13.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-08-14.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-08-15.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-08-16.tsv',
 'data_to_post/authors/OpenAlex_authors_updated_date=2023-08-17.tsv']

# %%
import pandas as pd 

file_authors = pd.concat( [ pd.read_csv( main_path  + elem , delimiter = "\t", usecols = ["author_id","display_name"]) for elem in list_files_authors])

# %%
file_authors = file_authors.rename(columns = { 'author_id' : 'authorid' , 'display_name' : 'authorname' })

# %%
file_authors
# Out:
#            authorid          authorname
# 0       A4347464006       Lucero Molina
# 0       A4330392039      Thibault Mayor
# 0       A4225353913    Valentina Politi
# 0       A4379737106          Dina Tarek
# 1       A4379737109          Yitian Sun
# ...             ...                 ...
# 304180  A5091901145          A. I. Bush
# 304181  A5091907166  Aleksandra Volkova
# 304182  A5091910692       K. V. Pavelec
# 304183  A5091913047       F. H. Gladwin
# 304184  A5091914373           G Koppány
#
# [91748427 rows x 2 columns]

# %%
file_authors.to_csv(main_path + "data_to_post/clean_files/" + 'authoridname.csv' , index = False)

# %% [markdown]
# ## Authors - works

# %%
list_works_authors = ['/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2021-11-03.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2021-12-23.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2021-12-30.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2022-01-30.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2022-02-02.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2022-02-03.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2022-02-17.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2022-03-09.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-04-07.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-04-09.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-04-12.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-04-13.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-04-14.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-04-15.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-04-16.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-04-17.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-04-24.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-04-25.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-04-26.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-04-27.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-04-29.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-04-30.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-01.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-03.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-04.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-05.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-06.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-07.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-08.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-09.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-10.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-11.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-12.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-13.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-14.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-15.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-16.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-17.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-18.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-19.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-20.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-21.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-22.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-23.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-24.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-25.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-26.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-27.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-28.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-29.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-30.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-05-31.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-01.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-02.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-03.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-04.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-05.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-06.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-07.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-08.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-09.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-10.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-11.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-12.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-13.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-14.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-15.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-16.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-17.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-18.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-19.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-20.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-21.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-22.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-23.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-24.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-25.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-26.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-27.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-28.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-29.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-06-30.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-01.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-02.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-03.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-04.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-05.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-06.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-07.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-08.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-09.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-10.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-11.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-12.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-13.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-14.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-15.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-16.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-17.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-18.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-19.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-20.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-21.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-22.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-23.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-24.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-25.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-26.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-27.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-28.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-29.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-30.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-07-31.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-08-01.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-08-02.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-08-03.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-08-04.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-08-05.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-08-06.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-08-07.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-08-08.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-08-09.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-08-10.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-08-11.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-08-12.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-08-13.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-08-14.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-08-15.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-08-16.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-08-17.tsv',
 '/home/fs01/spec1142/Emma/PPPs/data_to_post/authors/OpenAlex_authors_works_updated_date=2023-08-18.tsv']

# %%
def clear_authors_works_files(file):
    df = pd.read_csv(  file , delimiter = "\t")

# %%
import pandas as pd 
from tqdm import tqdm 

for file in tqdm(list_works_authors):
    df = pd.read_csv(  file , delimiter = "\t")
    df['work_id'] = [ 'W' + str(elem) for elem in df['work_id']]
    df['author_id'] = [ 'A' + str(elem) for elem in df['author_id']]
    df['institution_id'] = [ 'I' + str(elem).split('.')[0] if pd.isna(elem) == False else elem for elem in df['institution_id']]
    df.to_csv(  file , sep = "\t", index = False)
# Out:
#  93%|██████████████████████████████████████▏  | 122/131 [00:36<00:27,  3.08s/it]/tmp/ipykernel_4885/2115988506.py:5: DtypeWarning: Columns (0,1,2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(  file , delimiter = "\t")
#  94%|██████████████████████████████████████▍  | 123/131 [05:37<12:12, 91.60s/it]/tmp/ipykernel_4885/2115988506.py:5: DtypeWarning: Columns (0,1,2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(  file , delimiter = "\t")
#  95%|█████████████████████████████████████▊  | 124/131 [16:43<30:36, 262.35s/it]/tmp/ipykernel_4885/2115988506.py:5: DtypeWarning: Columns (0,1,2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(  file , delimiter = "\t")
# ...

# %%
df[df['institution_name'].notnull()]
# Out:
#            work_id   author_id   institution_id  institution_name
# 5255090   Wwork_id  Aauthor_id  Iinstitution_id  institution_name
# 7760433   Wwork_id  Aauthor_id  Iinstitution_id  institution_name
# 10033207  Wwork_id  Aauthor_id  Iinstitution_id  institution_name
# 12390008  Wwork_id  Aauthor_id  Iinstitution_id  institution_name
# 14710248  Wwork_id  Aauthor_id  Iinstitution_id  institution_name
# 17168091  Wwork_id  Aauthor_id  Iinstitution_id  institution_name
# 19380021  Wwork_id  Aauthor_id  Iinstitution_id  institution_name
# 21785479  Wwork_id  Aauthor_id  Iinstitution_id  institution_name
# 23955113  Wwork_id  Aauthor_id  Iinstitution_id  institution_name
# 26398893  Wwork_id  Aauthor_id  Iinstitution_id  institution_name
# 28899902  Wwork_id  Aauthor_id  Iinstitution_id  institution_name
# 33190149  Wwork_id  Aauthor_id  Iinstitution_id  institution_name
# 35420716  Wwork_id  Aauthor_id  Iinstitution_id  institution_name
# ...

# %%
file_authors_works = pd.concat( [ pd.read_csv(   elem , delimiter = "\t") for elem in list_works_authors[:-10]])

# %%
file_authors_works = file_authors_works.rename(columns = { 'work_id' : 'oaid' , 'author_id' : 'authorid' , 'institution_id' : 'affiliationid' , 'institution_name' : 'affiliationameifnoid' })

# %%
file_authors_works = file_authors_works[file_authors_works['oaid'] != 'Wwork_id']

# %%
file_authors_works[file_authors_works['affiliationameifnoid'].notnull()]
# Out:
#               oaid     authorid affiliationid  \
# 27     W2590154271  A2590585227           NaN
# 29     W2590154271  A2661761770           NaN
# 36      W631075702  A1987814616           NaN
# 67     W2594753679  A2592423679           NaN
# 96     W2994201468  A2688736441           NaN
# ...            ...          ...           ...
# 94872   W955277603  A4345380707           NaN
# 94927    W96478308  A2551780365           NaN
# 95143   W996452691   A341007127           NaN
# 1259   W4292532348  A2953613218           NaN
# 6      W2074879341  A4358424515           NaN
#
#                                     affiliationameifnoid
# 27     Clinical Instructor, King Fahad Medical City, ...
# 29     Clinical Instructor, Al Amal Complex for Menta...
# 36     Nurse Manager, Fairleigh Lodge, Auckland, New ...
# 67     Executive Director, CARE Centre for Internatio...
# 96                          WordMeridian Communications.
# ...                                                  ...
# ...

# %%
file_authors_works.to_csv(main_path + "data_to_post/clean_files/" + 'paperauthoridaffiliationIFAVAILABLE/file1.csv' , index = False)

# %%
k = 2

for elem in list_works_authors[-10:]:
    file_authors_works = pd.read_csv(   elem , delimiter = "\t")
    file_authors_works = file_authors_works.rename(columns = { 'work_id' : 'oaid' , 'author_id' : 'authorid' , 'institution_id' : 'affiliationid' , 'institution_name' : 'affiliationameifnoid' })                                            
    file_authors_works = file_authors_works[file_authors_works['oaid'] != 'Wwork_id'] 
    file_authors_works.to_csv(main_path + "data_to_post/clean_files/" + 'paperauthoridaffiliationIFAVAILABLE/file' + str(k) + '.csv' , index = False) 
    k += 1
    print(k)
# Out:
# 3
# /tmp/ipykernel_7767/1400383148.py:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   file_authors_works = pd.read_csv(   elem , delimiter = "\t")
# 4
# /tmp/ipykernel_7767/1400383148.py:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   file_authors_works = pd.read_csv(   elem , delimiter = "\t")
# 5
# /tmp/ipykernel_7767/1400383148.py:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   file_authors_works = pd.read_csv(   elem , delimiter = "\t")
# 6
# /tmp/ipykernel_7767/1400383148.py:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   file_authors_works = pd.read_csv(   elem , delimiter = "\t")
# 7
# /tmp/ipykernel_7767/1400383148.py:4: DtypeWarning: Columns (2,3) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %% [markdown]
# ## Works

# %%
path = '/home/fs01/spec1142/Emma/'

list_files_works = glob.glob(path + "PPPs/data_to_post/works/*" )[:128]

# %%
import pandas as pd 

file_works = pd.concat( [ pd.read_csv(  elem , delimiter = "\t", on_bad_lines = 'skip',lineterminator='\n', usecols = ['work_id', 'doi', 'pmid', 'venue_or_source', 'first_page', 'last_page',
       'volume', 'issue', 'cited_by_count','publication_date']) for elem in list_files_works])

file_works['work_id'] = [ "W" + str(elem) for elem in file_works['work_id'] ] 
file_works['venue_or_source'] = [ "S" + str(elem) for elem in file_works['venue_or_source'] ] 
file_works['paperyear'] = [ elem[:4] if pd.isna(elem) == False else elem for elem in file_works['venue_or_source'] ] 

file_works = file_works.rename(columns = {'work_id' : 'oaid', 'venue_or_source': 'journalid', 'volume': 'papervolume' , 'issue' : 'paperissue' , 'first_page': 'paperIstpage' , 'last_page' : 'paperlastpage' , 'cited_by_count':'numcitesfrompapers'   } ) 



file_works[file_works['paperyear'].notnull()][['oaid','paperyear']].to_csv(path + 'PPPs/data_to_post/clean_files/paperyear/file1.csv' , index = False)
file_works[file_works['doi'].notnull()][['oaid','doi']].to_csv(path + 'PPPs/data_to_post/clean_files/paperdoi/file1.csv'  , index = False)
file_works[file_works['pmid'].notnull()][['oaid','pmid']].to_csv(path + 'PPPs/data_to_post/clean_files/paperpmid/file1.csv'  , index = False)
file_works[file_works['journalid'].notnull()][['oaid','journalid']].to_csv(path + 'PPPs/data_to_post/clean_files/paperjournalid/file1.csv'  , index = False)
file_works[file_works['numcitesfrompapers'].notnull()][['oaid','numcitesfrompapers']].to_csv(path + 'PPPs/data_to_post/clean_files/paperncitesfrompapers/file1.csv'  , index = False)
file_works[['oaid','papervolume','paperissue','paperIstpage','paperlastpage']].to_csv(path + 'PPPs/data_to_post/clean_files/papervolisspages/file1.csv'  , index = False)
# Out:
# /tmp/ipykernel_7767/1543614590.py:3: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   file_works = pd.concat( [ pd.read_csv(  elem , delimiter = "\t", on_bad_lines = 'skip',lineterminator='\n', usecols = ['work_id', 'doi', 'pmid', 'venue_or_source', 'first_page', 'last_page',

# %%
import pandas as pd 

k = 2 
for day in range(10,19):

    list_files_works = glob.glob(path + "PPPs/data_to_post/works/OpenAlex_works_updated_date=2023-08-" + str(day) + '_*' )
    
    
    file_works = pd.concat( [ pd.read_csv(  elem , delimiter = "\t", on_bad_lines = 'skip',lineterminator='\n', usecols = ['work_id', 'doi', 'pmid', 'venue_or_source', 'first_page', 'last_page',
           'volume', 'issue', 'cited_by_count','publication_date']) for elem in list_files_works])
    
    file_works['work_id'] = [ "W" + str(elem) for elem in file_works['work_id'] ] 
    file_works['venue_or_source'] = [ "S" + str(elem) for elem in file_works['venue_or_source'] ] 
    file_works['paperyear'] = [ elem[:4] if pd.isna(elem) == False else elem for elem in file_works['venue_or_source'] ] 
    
    file_works = file_works.rename(columns = {'work_id' : 'oaid', 'venue_or_source': 'journalid', 'volume': 'papervolume' , 'issue' : 'paperissue' , 'first_page': 'paperIstpage' , 'last_page' : 'paperlastpage' , 'cited_by_count':'numcitesfrompapers'   } ) 
    
    
    
    file_works[file_works['paperyear'].notnull()][['oaid','paperyear']].to_csv(path + 'PPPs/data_to_post/clean_files/paperyear/file' + str(k) + '.tsv' , sep = '\t' , index = False)
    file_works[file_works['doi'].notnull()][['oaid','doi']].to_csv(path + 'PPPs/data_to_post/clean_files/paperdoi/file' + str(k) + '.tsv' , sep = '\t' , index = False)
    file_works[file_works['pmid'].notnull()][['oaid','pmid']].to_csv(path + 'PPPs/data_to_post/clean_files/paperyear/file' + str(k) + '.tsv' , sep = '\t' , index = False)
    file_works[file_works['journalid'].notnull()][['oaid','journalid']].to_csv(path + 'PPPs/data_to_post/clean_files/paperjournalid/file' + str(k) + '.tsv' , sep = '\t' , index = False)
    file_works[file_works['numcitesfrompapers'].notnull()][['oaid','numcitesfrompapers']].to_csv(path + 'PPPs/data_to_post/clean_files/paperncitesfrompapers/file' + str(k) + '.tsv' , sep = '\t' , index = False)
    file_works[file_works['pmid'].notnull()][['oaid','papervolume','paperissue','paperIstpage','paperlastpage']].to_csv(path + 'PPPs/data_to_post/clean_files/papervolisspages/file' + str(k) + '.tsv' , sep = '\t' , index = False)
    
    print(day)
    k += 1
# Out:
# /tmp/ipykernel_7767/340874157.py:9: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   file_works = pd.concat( [ pd.read_csv(  elem , delimiter = "\t", on_bad_lines = 'skip',lineterminator='\n', usecols = ['work_id', 'doi', 'pmid', 'venue_or_source', 'first_page', 'last_page',
# /tmp/ipykernel_7767/340874157.py:9: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   file_works = pd.concat( [ pd.read_csv(  elem , delimiter = "\t", on_bad_lines = 'skip',lineterminator='\n', usecols = ['work_id', 'doi', 'pmid', 'venue_or_source', 'first_page', 'last_page',
# /tmp/ipykernel_7767/340874157.py:9: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   file_works = pd.concat( [ pd.read_csv(  elem , delimiter = "\t", on_bad_lines = 'skip',lineterminator='\n', usecols = ['work_id', 'doi', 'pmid', 'venue_or_source', 'first_page', 'last_page',
# ...

# %%
import pandas as pd 


def clean_files(k):

    day = k + 8

    list_files_works = glob.glob(path + "PPPs/data_to_post/works/OpenAlex_works_updated_date=2023-08-" + str(day) + '_*' )
    
    
    file_works = pd.concat( [ pd.read_csv(  elem , delimiter = "\t", on_bad_lines = 'skip',lineterminator='\n', usecols = ['work_id', 'doi', 'pmid', 'venue_or_source', 'first_page', 'last_page',
           'volume', 'issue', 'cited_by_count','publication_date']) for elem in list_files_works])
    
    file_works['work_id'] = [ "W" + str(elem) for elem in file_works['work_id'] ] 
    file_works['venue_or_source'] = [ "S" + str(elem) for elem in file_works['venue_or_source'] ] 
    file_works['paperyear'] = [ elem[:4] if pd.isna(elem) == False else elem for elem in file_works['venue_or_source'] ] 
    
    file_works = file_works.rename(columns = {'work_id' : 'oaid', 'venue_or_source': 'journalid', 'volume': 'papervolume' , 'issue' : 'paperissue' , 'first_page': 'paperIstpage' , 'last_page' : 'paperlastpage' , 'cited_by_count':'numcitesfrompapers'   } ) 
    
    
    
    file_works[file_works['paperyear'].notnull()][['oaid','paperyear']].to_csv(path + 'PPPs/data_to_post/clean_files/paperyear/file' + str(k) + '.csv'  , index = False)
    file_works[file_works['doi'].notnull()][['oaid','doi']].to_csv(path + 'PPPs/data_to_post/clean_files/paperdoi/file' + str(k) + '.csv'  , index = False)
    file_works[file_works['pmid'].notnull()][['oaid','pmid']].to_csv(path + 'PPPs/data_to_post/clean_files/paperpmid/file' + str(k) + '.csv' , index = False)
    file_works[file_works['journalid'].notnull()][['oaid','journalid']].to_csv(path + 'PPPs/data_to_post/clean_files/paperjournalid/file' + str(k) + '.csv'  , index = False)
    file_works[file_works['numcitesfrompapers'].notnull()][['oaid','numcitesfrompapers']].to_csv(path + 'PPPs/data_to_post/clean_files/paperncitesfrompapers/file' + str(k) + '.csv' , index = False)
    file_works[['oaid','papervolume','paperissue','paperIstpage','paperlastpage']].to_csv(path + 'PPPs/data_to_post/clean_files/papervolisspages/file' + str(k) + '.csv'  , index = False)

# %%
import warnings

        
from multiprocessing import Process


if __name__ == '__main__':
    with warnings.catch_warnings():
        warnings.simplefilter("ignore",UserWarning)
        
        processes = [Process(target=clean_files, args=(k,)) for k in range(2,11)]
        
        for process in processes:
            process.start()
            
        for process in processes:
            process.join()
# Out:
# /tmp/ipykernel_7767/121244116.py:11: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   file_works = pd.concat( [ pd.read_csv(  elem , delimiter = "\t", on_bad_lines = 'skip',lineterminator='\n', usecols = ['work_id', 'doi', 'pmid', 'venue_or_source', 'first_page', 'last_page',
# /tmp/ipykernel_7767/121244116.py:11: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   file_works = pd.concat( [ pd.read_csv(  elem , delimiter = "\t", on_bad_lines = 'skip',lineterminator='\n', usecols = ['work_id', 'doi', 'pmid', 'venue_or_source', 'first_page', 'last_page',
# /tmp/ipykernel_7767/121244116.py:11: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
import pandas as pd 

twins = pd.read_stata('/home/fs01/spec1142/Emma/PPPs_twins/biobikardtwins.dta')

# %%
twins[twins['citationtwin'] == 1]
# Out:
#               magid  citationtwin  biotwin  biocitationtwin  pairid
# 4      2.071633e+09             1        0                0       2
# 5      1.011480e+08             1        0                0       2
# 6      1.256453e+09             1        0                0       3
# 7      1.012564e+07             1        0                0       3
# 8      1.019169e+07             1        0                0       4
# ...             ...           ...      ...              ...     ...
# 33307  1.516426e+09             1        0                0   17036
# 33308  2.184876e+09             1        0                0   17037
# 33309  9.814123e+08             1        0                0   17037
# 33312  2.066652e+09             1        0                0   17039
# 33313  9.913784e+08             1        0                0   17039
#
# [27168 rows x 5 columns]
